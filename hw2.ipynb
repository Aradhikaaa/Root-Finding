# %%
import numpy as np
import matplotlib.pyplot as plt
from methods import methods

# %% [markdown]
# ## Defining the function and the derivative of it
# ### $f(x)= x^3 - 7x^2 + 14x -5$
# ### $f'(x) = 3x^2 - 14x +14$
# The derivative is needed for the Newton Raphson Method

# %%
# Defining the function

def func(x):
    return (x**3 - 7* x**2 + 14*x -5)

def dfunc(x):
    return (3*x**2 - 14*x + 14)

# %% [markdown]
# ## Bisection Method

# %%
m = methods()
n=1

while True:
    print("Enter you initial guesses for the interval: ")
    x1 = float(input("x1: "))
    x2 = float(input("x2: "))
    print(f"The intervals are {{{x1}, {x2}}}")
    tol =10e-8
    n1,r1 = m.bisection(func,x1,x2,tol)
    print("The root is: ", r1)
    print("The number of iterations is: ", n1)
    n=int(input("Enter 0 to end or any number to continue", ))
    #print("n =",n)

    if(n==0):
        break
# Out:
# Enter you initial guesses for the interval:
# The intervals are {0.0, 1.0}
# The root lies between:  0.0 and 0.5 so we continue the search
# The root lies between:  0.25 and 0.5 so we continue the search
# The root lies between:  0.375 and 0.5 so we continue the search
# The root lies between:  0.4375 and 0.5 so we continue the search
# The root lies between:  0.4375 and 0.46875 so we continue the search
# The root lies between:  0.453125 and 0.46875 so we continue the search
# The root lies between:  0.453125 and 0.4609375 so we continue the search
# The root lies between:  0.453125 and 0.45703125 so we continue the search
# The root lies between:  0.453125 and 0.455078125 so we continue the search
# The root lies between:  0.453125 and 0.4541015625 so we continue the search
# The root lies between:  0.453125 and 0.45361328125 so we continue the search
# The root lies between:  0.453125 and 0.453369140625 so we continue the search
# The root lies between:  0.453125 and 0.4532470703125 so we continue the search
# The root lies between:  0.453125 and 0.45318603515625 so we continue the search
# The root lies between:  0.453155517578125 and 0.45318603515625 so we continue the search
# The root lies between:  0.4531707763671875 and 0.45318603515625 so we continue the search
# The root lies between:  0.45317840576171875 and 0.45318603515625 so we continue the search
# The root lies between:  0.45317840576171875 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45318031311035156 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45318126678466797 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45318126678466797 and 0.45318174362182617 so we continue the search
# The root lies between:  0.45318150520324707 and 0.45318174362182617 so we continue the search
# The root lies between:  0.4531816244125366 and 0.45318174362182617 so we continue the search
# The root lies between:  0.4531816840171814 and 0.45318174362182617 so we continue the search
# The root is:  0.4531816840171814
# The number of iterations is:  24
# Enter you initial guesses for the interval:
# The intervals are {-1.0, 2.0}
# The root lies between:  -1.0 and 0.5 so we continue the search
# The root lies between:  -0.25 and 0.5 so we continue the search
# The root lies between:  0.125 and 0.5 so we continue the search
# The root lies between:  0.3125 and 0.5 so we continue the search
# The root lies between:  0.40625 and 0.5 so we continue the search
# The root lies between:  0.453125 and 0.5 so we continue the search
# The root lies between:  0.453125 and 0.4765625 so we continue the search
# The root lies between:  0.453125 and 0.46484375 so we continue the search
# The root lies between:  0.453125 and 0.458984375 so we continue the search
# The root lies between:  0.453125 and 0.4560546875 so we continue the search
# The root lies between:  0.453125 and 0.45458984375 so we continue the search
# The root lies between:  0.453125 and 0.453857421875 so we continue the search
# The root lies between:  0.453125 and 0.4534912109375 so we continue the search
# The root lies between:  0.453125 and 0.45330810546875 so we continue the search
# The root lies between:  0.453125 and 0.453216552734375 so we continue the search
# The root lies between:  0.4531707763671875 and 0.453216552734375 so we continue the search
# The root lies between:  0.4531707763671875 and 0.45319366455078125 so we continue the search
# The root lies between:  0.4531707763671875 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45317649841308594 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45317935943603516 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45318078994750977 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45318150520324707 and 0.4531822204589844 so we continue the search
# The root lies between:  0.45318150520324707 and 0.4531818628311157 so we continue the search
# The root lies between:  0.4531816840171814 and 0.4531818628311157 so we continue the search
# The root lies between:  0.4531816840171814 and 0.45318177342414856 so we continue the search
# The root is:  0.45318177342414856
# The number of iterations is:  25
# Enter you initial guesses for the interval:
# The intervals are {-10.0, 10.0}
# The root lies between:  0.0 and 10.0 so we continue the search
# The root lies between:  0.0 and 5.0 so we continue the search
# The root lies between:  0.0 and 2.5 so we continue the search
# The root lies between:  0.0 and 1.25 so we continue the search
# The root lies between:  0.0 and 0.625 so we continue the search
# The root lies between:  0.3125 and 0.625 so we continue the search
# The root lies between:  0.3125 and 0.46875 so we continue the search
# The root lies between:  0.390625 and 0.46875 so we continue the search
# The root lies between:  0.4296875 and 0.46875 so we continue the search
# The root lies between:  0.44921875 and 0.46875 so we continue the search
# The root lies between:  0.44921875 and 0.458984375 so we continue the search
# The root lies between:  0.44921875 and 0.4541015625 so we continue the search
# The root lies between:  0.45166015625 and 0.4541015625 so we continue the search
# The root lies between:  0.452880859375 and 0.4541015625 so we continue the search
# The root lies between:  0.452880859375 and 0.4534912109375 so we continue the search
# The root lies between:  0.452880859375 and 0.45318603515625 so we continue the search
# The root lies between:  0.453033447265625 and 0.45318603515625 so we continue the search
# The root lies between:  0.4531097412109375 and 0.45318603515625 so we continue the search
# The root lies between:  0.45314788818359375 and 0.45318603515625 so we continue the search
# The root lies between:  0.4531669616699219 and 0.45318603515625 so we continue the search
# The root lies between:  0.45317649841308594 and 0.45318603515625 so we continue the search
# The root lies between:  0.45318126678466797 and 0.45318603515625 so we continue the search
# The root lies between:  0.45318126678466797 and 0.453183650970459 so we continue the search
# The root lies between:  0.45318126678466797 and 0.4531824588775635 so we continue the search
# The root lies between:  0.45318126678466797 and 0.4531818628311157 so we continue the search
# The root lies between:  0.45318156480789185 and 0.4531818628311157 so we continue the search
# The root lies between:  0.4531817138195038 and 0.4531818628311157 so we continue the search
# The root lies between:  0.4531817138195038 and 0.45318178832530975 so we continue the search
# The root is:  0.45318178832530975
# The number of iterations is:  28
# Enter you initial guesses for the interval:
# The intervals are {4.0, 9.0}
# You have not chosen a valid interval
# The root is:  6.5
# The number of iterations is:  0
# Enter you initial guesses for the interval:
# The intervals are {-9.0, 2.0}
# The root lies between:  -3.5 and 2.0 so we continue the search
# The root lies between:  -0.75 and 2.0 so we continue the search
# The root lies between:  -0.75 and 0.625 so we continue the search
# The root lies between:  -0.0625 and 0.625 so we continue the search
# The root lies between:  0.28125 and 0.625 so we continue the search
# The root lies between:  0.453125 and 0.625 so we continue the search
# The root lies between:  0.453125 and 0.5390625 so we continue the search
# The root lies between:  0.453125 and 0.49609375 so we continue the search
# The root lies between:  0.453125 and 0.474609375 so we continue the search
# The root lies between:  0.453125 and 0.4638671875 so we continue the search
# The root lies between:  0.453125 and 0.45849609375 so we continue the search
# The root lies between:  0.453125 and 0.455810546875 so we continue the search
# The root lies between:  0.453125 and 0.4544677734375 so we continue the search
# The root lies between:  0.453125 and 0.45379638671875 so we continue the search
# The root lies between:  0.453125 and 0.453460693359375 so we continue the search
# The root lies between:  0.453125 and 0.4532928466796875 so we continue the search
# The root lies between:  0.453125 and 0.45320892333984375 so we continue the search
# The root lies between:  0.4531669616699219 and 0.45320892333984375 so we continue the search
# The root lies between:  0.4531669616699219 and 0.4531879425048828 so we continue the search
# The root lies between:  0.45317745208740234 and 0.4531879425048828 so we continue the search
# The root lies between:  0.45317745208740234 and 0.4531826972961426 so we continue the search
# The root lies between:  0.45318007469177246 and 0.4531826972961426 so we continue the search
# The root lies between:  0.4531813859939575 and 0.4531826972961426 so we continue the search
# The root lies between:  0.4531813859939575 and 0.45318204164505005 so we continue the search
# The root lies between:  0.4531817138195038 and 0.45318204164505005 so we continue the search
# The root lies between:  0.4531817138195038 and 0.4531818777322769 so we continue the search
# The root lies between:  0.4531817138195038 and 0.45318179577589035 so we continue the search
# The root is:  0.45318179577589035
# The number of iterations is:  27

# %%
m = methods()
n=1
while True:
    print("Enter your initial guess:")
    x0 = float(input("x0 : "))
    print(f"The intial guess is",x0)
    tol =10e-8
    n2,r2 =m.newton(func,dfunc,x0,tol)
    print("The root is: ", r2)
    print("The number of iteration is: ", n2)
    n=int(input("Enter 0 to end or any number to continue", ))

    if(n==0):
        break
# Out:
# Enter your initial guess:
# The intial guess is 1.0
# The root is:  0.0
# The root is:  0.35714285714285715
# The root is:  0.44744814728501514
# The root is:  0.453159435118196
# The root is:  0.4531817227771845
# The root is:  0.4531817227771845
# The number of iteration is:  5
# Enter your initial guess:
# The intial guess is 2.5
# The root is:  3.3333333333333335
# The root is:  1.9444444444444322
# The root is:  3.597883597883621
# The root is:  3.0577834358483313
# The root is:  4.308475930708071
# The root is:  3.736878916578236
# The root is:  3.2477899582530907
# The root is:  -1.8287780509481943
# The root is:  -0.6173609910943756
# The root is:  0.0782572425515966
# The root is:  0.38367073745392016
# The root is:  0.450102950414619
# The root is:  0.4531752794398619
# The root is:  0.4531817230876046
# The root is:  0.4531817230876046
# The number of iteration is:  14
# Enter your initial guess:
# The intial guess is -5.0
# The root is:  -2.641509433962264
# The root is:  -1.1222546350668827
# The root is:  -0.19835955089997448
# The root is:  0.2787182297748707
# The root is:  0.4355356156116562
# The root is:  0.45297310274993413
# The root is:  0.4531816934438516
# The root is:  0.4531816934438516
# The number of iteration is:  7
# Enter your initial guess:
# The intial guess is 3.21525
# The root is:  383738.6573928133
# The root is:  255826.5493743379
# The root is:  170551.81069602986
# The root is:  113701.98491150461
# The root is:  75802.10105667455
# The root is:  50535.51182240131
# The root is:  33691.11900297264
# The root is:  22461.523795150304
# The root is:  14975.126997630297
# The root is:  9984.19581082533
# The root is:  6656.908370266508
# The root is:  4438.716769190883
# The root is:  2959.922407412093
# The root is:  1974.0595579510673
# The root is:  1316.8177458617668
# The root is:  878.6566690486093
# The root is:  586.549481194513
# The root is:  391.81165058201606
# The root is:  261.98687119021906
# The root is:  175.4376777204592
# The root is:  117.73919994660835
# The root is:  79.27501445660408
# The root is:  53.63440018509631
# The root is:  36.54386868557391
# The root is:  25.154879778789258
# The root is:  17.569004062783343
# The root is:  12.521339551234085
# The root is:  9.169306464341686
# The root is:  6.951395764530822
# The root is:  5.4919232019177855
# The root is:  4.5352344276135454
# The root is:  3.896742502105756
# The root is:  3.410152291377451
# The root is:  2.541114172200536
# The root is:  3.3503509000500014
# The root is:  2.1314126387038943
# The root is:  3.362599151637232
# The root is:  2.240444595510466
# The root is:  3.3131438571311667
# The root is:  1.6420392301089581
# The root is:  5.578944045272676
# The root is:  4.592379539586809
# The root is:  3.936062718827526
# The root is:  3.4453483601010806
# The root is:  2.6900076059970806
# The root is:  3.4444301274800404
# The root is:  2.6866339059477227
# The root is:  3.441656499069804
# The root is:  2.6763003104461967
# The root is:  3.4333715232544084
# The root is:  2.6440837308515364
# The root is:  3.409475872633408
# The root is:  2.5377876557887764
# The root is:  3.348839999691571
# The root is:  2.1166539685936456
# The root is:  3.3730699776369577
# The root is:  2.320979399624851
# The root is:  3.301778951222475
# The root is:  1.4117238153419696
# The root is:  -15.476508126692279
# The root is:  -9.57146010608469
# The root is:  -5.652334488734667
# The root is:  -3.0681331214012393
# The root is:  -1.3927882933764475
# The root is:  -0.35562395806300584
# The root is:  0.20791102297965403
# The root is:  0.4203063203796146
# The root is:  0.4524683935287318
# The root is:  0.4531813763840612
# The root is:  0.45318172311583593
# The root is:  0.45318172311583593
# The number of iteration is:  70
