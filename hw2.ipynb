# %%
import numpy as np
import matplotlib.pyplot as plt
from methods import methods

# %% [markdown]
# ## Defining the function and the derivative of it
# ### $f(x)= x^3 - 7x^2 + 14x -5$
# ### $f'(x) = 3x^2 - 14x +14$
# The derivative is needed for the Newton Raphson Method

# %%
# Defining the function

def func(x):
    return (x**3 - 7* x**2 + 14*x -5)

def dfunc(x):
    return (3*x**2 - 14*x + 14)

# %% [markdown]
# ## Bisection Method

# %%
m = methods()
n=1

x1=0
x2=1
print(f"The intervals are {{{x1}, {x2}}}")
tol=1e-8
n1,r1 = m.bisection(func,x1,x2,tol)
if r1 is not None:
    print("The root is: ", r1)
    print("The number of iterations is: ", n1)
# Out:
# The intervals are {0, 1}
# Iter 1 : interval = [ 0 , 1 ] , c = 0.5 , f(c) = 0.375 , error = 2.0
# Iter 2 : interval = [ 0 , 0.5 ] , c = 0.25 , f(c) = -1.921875 , error = 2.0
# Iter 3 : interval = [ 0.25 , 0.5 ] , c = 0.375 , f(c) = -0.681640625 , error = 0.6666666666666666
# Iter 4 : interval = [ 0.375 , 0.5 ] , c = 0.4375 , f(c) = -0.131103515625 , error = 0.2857142857142857
# Iter 5 : interval = [ 0.4375 , 0.5 ] , c = 0.46875 , f(c) = 0.127410888671875 , error = 0.13333333333333333
# Iter 6 : interval = [ 0.4375 , 0.46875 ] , c = 0.453125 , f(c) = -0.000469207763671875 , error = 0.06896551724137931
# Iter 7 : interval = [ 0.453125 , 0.46875 ] , c = 0.4609375 , f(c) = 0.06381368637084961 , error = 0.03389830508474576
# Iter 8 : interval = [ 0.453125 , 0.4609375 ] , c = 0.45703125 , f(c) = 0.031758129596710205 , error = 0.017094017094017096
# Iter 9 : interval = [ 0.453125 , 0.45703125 ] , c = 0.455078125 , f(c) = 0.01566595584154129 , error = 0.008583690987124463
# Iter 10 : interval = [ 0.453125 , 0.455078125 ] , c = 0.4541015625 , f(c) = 0.007603750564157963 , error = 0.004301075268817204
# Iter 11 : interval = [ 0.453125 , 0.4541015625 ] , c = 0.45361328125 , f(c) = 0.003568615880794823 , error = 0.002152852529601722
# Iter 12 : interval = [ 0.453125 , 0.45361328125 ] , c = 0.453369140625 , f(c) = 0.0015500402223551646 , error = 0.0010770059235325794
# Iter 13 : interval = [ 0.453125 , 0.453369140625 ] , c = 0.4532470703125 , f(c) = 0.0005405002757470356 , error = 0.0005386479935362241
# Iter 14 : interval = [ 0.453125 , 0.4532470703125 ] , c = 0.45318603515625 , f(c) = 3.566726832104905e-05 , error = 0.00026936026936026934
# Iter 15 : interval = [ 0.453125 , 0.45318603515625 ] , c = 0.453155517578125 , f(c) = -0.00021676499451928066 , error = 0.00013468920466024647
# Iter 16 : interval = [ 0.453155517578125 , 0.45318603515625 ] , c = 0.4531707763671875 , f(c) = -9.054754982074087e-05 , error = 6.734233475874608e-05
# Iter 17 : interval = [ 0.4531707763671875 , 0.45318603515625 ] , c = 0.45317840576171875 , f(c) = -2.7439812431140354e-05 , error = 3.367060051516019e-05
# Iter 18 : interval = [ 0.45317840576171875 , 0.45318603515625 ] , c = 0.4531822204589844 , f(c) = 4.113810024186648e-06 , error = 1.68351585451056e-05
# Iter 19 : interval = [ 0.45317840576171875 , 0.4531822204589844 ] , c = 0.45318031311035156 , f(c) = -1.1662980684334912e-05 , error = 8.417614700522313e-06
# Iter 20 : interval = [ 0.45318031311035156 , 0.4531822204589844 ] , c = 0.45318126678466797 , f(c) = -3.7745802003996687e-06 , error = 4.20879849325014e-06
# Iter 21 : interval = [ 0.45318126678466797 , 0.4531822204589844 ] , c = 0.45318174362182617 , f(c) = 1.6961619486721702e-07 , error = 2.104397032379305e-06
# Iter 22 : interval = [ 0.45318126678466797 , 0.45318174362182617 ] , c = 0.45318150520324707 , f(c) = -1.8024816821338163e-06 , error = 1.0521990697508024e-06
# Iter 23 : interval = [ 0.45318150520324707 , 0.45318174362182617 ] , c = 0.4531816244125366 , f(c) = -8.164326636972419e-07 , error = 5.260993964850773e-07
# Iter 24 : interval = [ 0.4531816244125366 , 0.45318174362182617 ] , c = 0.4531816840171814 , f(c) = -3.234082139869088e-07 , error = 2.6304966364497134e-07
# Iter 25 : interval = [ 0.4531816840171814 , 0.45318174362182617 ] , c = 0.4531817138195038 , f(c) = -7.689600511895378e-08 , error = 1.3152482317309555e-07
# Iter 26 : interval = [ 0.4531817138195038 , 0.45318174362182617 ] , c = 0.453181728720665 , f(c) = 4.636009620639925e-08 , error = 6.576240942420046e-08
# Iter 27 : interval = [ 0.4531817138195038 , 0.453181728720665 ] , c = 0.4531817212700844 , f(c) = -1.5267954012188056e-08 , error = 3.2881205252687045e-08
# Iter 28 : interval = [ 0.4531817212700844 , 0.453181728720665 ] , c = 0.4531817249953747 , f(c) = 1.5546071097105596e-08 , error = 1.644060249119682e-08
# The root is:  0.4531817249953747
# The number of iterations is:  28

# %% [markdown]
# ### Sensitivity of iteration count to initial guess

# %%
print("BISECTION: Effect of initial interval on iteration count")
print('\n')

intervals = [(0, 1), (0, 0.5), (-5, 5), (0.4, 0.45)]

for (x1, x2) in intervals:
    print(f"For Interval [{x1},{x2}]")
    n1, r1 = m.bisection(func, x1, x2, tol)
    if r1 is not None:
        print("  Interval [",x1,",", x2,"] : root = ",r1,", iterations = ",n1)


print("NEWTON-RAPHSON: Effect of initial guess on iteration count")
print('\n')
# Out:
# BISECTION: Effect of initial interval on iteration count
#
#
# For Interval [0,1]
# Iter 1 : interval = [ 0 , 1 ] , c = 0.5 , f(c) = 0.375 , error = 2.0
# Iter 2 : interval = [ 0 , 0.5 ] , c = 0.25 , f(c) = -1.921875 , error = 2.0
# Iter 3 : interval = [ 0.25 , 0.5 ] , c = 0.375 , f(c) = -0.681640625 , error = 0.6666666666666666
# Iter 4 : interval = [ 0.375 , 0.5 ] , c = 0.4375 , f(c) = -0.131103515625 , error = 0.2857142857142857
# Iter 5 : interval = [ 0.4375 , 0.5 ] , c = 0.46875 , f(c) = 0.127410888671875 , error = 0.13333333333333333
# Iter 6 : interval = [ 0.4375 , 0.46875 ] , c = 0.453125 , f(c) = -0.000469207763671875 , error = 0.06896551724137931
# Iter 7 : interval = [ 0.453125 , 0.46875 ] , c = 0.4609375 , f(c) = 0.06381368637084961 , error = 0.03389830508474576
# Iter 8 : interval = [ 0.453125 , 0.4609375 ] , c = 0.45703125 , f(c) = 0.031758129596710205 , error = 0.017094017094017096
# Iter 9 : interval = [ 0.453125 , 0.45703125 ] , c = 0.455078125 , f(c) = 0.01566595584154129 , error = 0.008583690987124463
# Iter 10 : interval = [ 0.453125 , 0.455078125 ] , c = 0.4541015625 , f(c) = 0.007603750564157963 , error = 0.004301075268817204
# Iter 11 : interval = [ 0.453125 , 0.4541015625 ] , c = 0.45361328125 , f(c) = 0.003568615880794823 , error = 0.002152852529601722
# Iter 12 : interval = [ 0.453125 , 0.45361328125 ] , c = 0.453369140625 , f(c) = 0.0015500402223551646 , error = 0.0010770059235325794
# Iter 13 : interval = [ 0.453125 , 0.453369140625 ] , c = 0.4532470703125 , f(c) = 0.0005405002757470356 , error = 0.0005386479935362241
# Iter 14 : interval = [ 0.453125 , 0.4532470703125 ] , c = 0.45318603515625 , f(c) = 3.566726832104905e-05 , error = 0.00026936026936026934
# Iter 15 : interval = [ 0.453125 , 0.45318603515625 ] , c = 0.453155517578125 , f(c) = -0.00021676499451928066 , error = 0.00013468920466024647
# Iter 16 : interval = [ 0.453155517578125 , 0.45318603515625 ] , c = 0.4531707763671875 , f(c) = -9.054754982074087e-05 , error = 6.734233475874608e-05
# Iter 17 : interval = [ 0.4531707763671875 , 0.45318603515625 ] , c = 0.45317840576171875 , f(c) = -2.7439812431140354e-05 , error = 3.367060051516019e-05
# Iter 18 : interval = [ 0.45317840576171875 , 0.45318603515625 ] , c = 0.4531822204589844 , f(c) = 4.113810024186648e-06 , error = 1.68351585451056e-05
# Iter 19 : interval = [ 0.45317840576171875 , 0.4531822204589844 ] , c = 0.45318031311035156 , f(c) = -1.1662980684334912e-05 , error = 8.417614700522313e-06
# Iter 20 : interval = [ 0.45318031311035156 , 0.4531822204589844 ] , c = 0.45318126678466797 , f(c) = -3.7745802003996687e-06 , error = 4.20879849325014e-06
# Iter 21 : interval = [ 0.45318126678466797 , 0.4531822204589844 ] , c = 0.45318174362182617 , f(c) = 1.6961619486721702e-07 , error = 2.104397032379305e-06
# Iter 22 : interval = [ 0.45318126678466797 , 0.45318174362182617 ] , c = 0.45318150520324707 , f(c) = -1.8024816821338163e-06 , error = 1.0521990697508024e-06
# Iter 23 : interval = [ 0.45318150520324707 , 0.45318174362182617 ] , c = 0.4531816244125366 , f(c) = -8.164326636972419e-07 , error = 5.260993964850773e-07
# Iter 24 : interval = [ 0.4531816244125366 , 0.45318174362182617 ] , c = 0.4531816840171814 , f(c) = -3.234082139869088e-07 , error = 2.6304966364497134e-07
# Iter 25 : interval = [ 0.4531816840171814 , 0.45318174362182617 ] , c = 0.4531817138195038 , f(c) = -7.689600511895378e-08 , error = 1.3152482317309555e-07
# Iter 26 : interval = [ 0.4531817138195038 , 0.45318174362182617 ] , c = 0.453181728720665 , f(c) = 4.636009620639925e-08 , error = 6.576240942420046e-08
# Iter 27 : interval = [ 0.4531817138195038 , 0.453181728720665 ] , c = 0.4531817212700844 , f(c) = -1.5267954012188056e-08 , error = 3.2881205252687045e-08
# Iter 28 : interval = [ 0.4531817212700844 , 0.453181728720665 ] , c = 0.4531817249953747 , f(c) = 1.5546071097105596e-08 , error = 1.644060249119682e-08
#   Interval [ 0 , 1 ] : root =  0.4531817249953747 , iterations =  28
# For Interval [0,0.5]
# Iter 1 : interval = [ 0 , 0.5 ] , c = 0.25 , f(c) = -1.921875 , error = 2.0
# Iter 2 : interval = [ 0.25 , 0.5 ] , c = 0.375 , f(c) = -0.681640625 , error = 0.6666666666666666
# Iter 3 : interval = [ 0.375 , 0.5 ] , c = 0.4375 , f(c) = -0.131103515625 , error = 0.2857142857142857
# Iter 4 : interval = [ 0.4375 , 0.5 ] , c = 0.46875 , f(c) = 0.127410888671875 , error = 0.13333333333333333
# Iter 5 : interval = [ 0.4375 , 0.46875 ] , c = 0.453125 , f(c) = -0.000469207763671875 , error = 0.06896551724137931
# Iter 6 : interval = [ 0.453125 , 0.46875 ] , c = 0.4609375 , f(c) = 0.06381368637084961 , error = 0.03389830508474576
# Iter 7 : interval = [ 0.453125 , 0.4609375 ] , c = 0.45703125 , f(c) = 0.031758129596710205 , error = 0.017094017094017096
# Iter 8 : interval = [ 0.453125 , 0.45703125 ] , c = 0.455078125 , f(c) = 0.01566595584154129 , error = 0.008583690987124463
# Iter 9 : interval = [ 0.453125 , 0.455078125 ] , c = 0.4541015625 , f(c) = 0.007603750564157963 , error = 0.004301075268817204
# Iter 10 : interval = [ 0.453125 , 0.4541015625 ] , c = 0.45361328125 , f(c) = 0.003568615880794823 , error = 0.002152852529601722
# Iter 11 : interval = [ 0.453125 , 0.45361328125 ] , c = 0.453369140625 , f(c) = 0.0015500402223551646 , error = 0.0010770059235325794
# Iter 12 : interval = [ 0.453125 , 0.453369140625 ] , c = 0.4532470703125 , f(c) = 0.0005405002757470356 , error = 0.0005386479935362241
# Iter 13 : interval = [ 0.453125 , 0.4532470703125 ] , c = 0.45318603515625 , f(c) = 3.566726832104905e-05 , error = 0.00026936026936026934
# Iter 14 : interval = [ 0.453125 , 0.45318603515625 ] , c = 0.453155517578125 , f(c) = -0.00021676499451928066 , error = 0.00013468920466024647
# Iter 15 : interval = [ 0.453155517578125 , 0.45318603515625 ] , c = 0.4531707763671875 , f(c) = -9.054754982074087e-05 , error = 6.734233475874608e-05
# Iter 16 : interval = [ 0.4531707763671875 , 0.45318603515625 ] , c = 0.45317840576171875 , f(c) = -2.7439812431140354e-05 , error = 3.367060051516019e-05
# Iter 17 : interval = [ 0.45317840576171875 , 0.45318603515625 ] , c = 0.4531822204589844 , f(c) = 4.113810024186648e-06 , error = 1.68351585451056e-05
# Iter 18 : interval = [ 0.45317840576171875 , 0.4531822204589844 ] , c = 0.45318031311035156 , f(c) = -1.1662980684334912e-05 , error = 8.417614700522313e-06
# Iter 19 : interval = [ 0.45318031311035156 , 0.4531822204589844 ] , c = 0.45318126678466797 , f(c) = -3.7745802003996687e-06 , error = 4.20879849325014e-06
# Iter 20 : interval = [ 0.45318126678466797 , 0.4531822204589844 ] , c = 0.45318174362182617 , f(c) = 1.6961619486721702e-07 , error = 2.104397032379305e-06
# Iter 21 : interval = [ 0.45318126678466797 , 0.45318174362182617 ] , c = 0.45318150520324707 , f(c) = -1.8024816821338163e-06 , error = 1.0521990697508024e-06
# Iter 22 : interval = [ 0.45318150520324707 , 0.45318174362182617 ] , c = 0.4531816244125366 , f(c) = -8.164326636972419e-07 , error = 5.260993964850773e-07
# Iter 23 : interval = [ 0.4531816244125366 , 0.45318174362182617 ] , c = 0.4531816840171814 , f(c) = -3.234082139869088e-07 , error = 2.6304966364497134e-07
# Iter 24 : interval = [ 0.4531816840171814 , 0.45318174362182617 ] , c = 0.4531817138195038 , f(c) = -7.689600511895378e-08 , error = 1.3152482317309555e-07
# Iter 25 : interval = [ 0.4531817138195038 , 0.45318174362182617 ] , c = 0.453181728720665 , f(c) = 4.636009620639925e-08 , error = 6.576240942420046e-08
# Iter 26 : interval = [ 0.4531817138195038 , 0.453181728720665 ] , c = 0.4531817212700844 , f(c) = -1.5267954012188056e-08 , error = 3.2881205252687045e-08
# Iter 27 : interval = [ 0.4531817212700844 , 0.453181728720665 ] , c = 0.4531817249953747 , f(c) = 1.5546071097105596e-08 , error = 1.644060249119682e-08
#   Interval [ 0 , 0.5 ] : root =  0.4531817249953747 , iterations =  27
# For Interval [-5,5]
# Iter 1 : interval = [ -5 , 5 ] , c = 0.0 , f(c) = -5.0 , error = 1e+17
# Iter 2 : interval = [ 0.0 , 5 ] , c = 2.5 , f(c) = 1.875 , error = 2.0
# Iter 3 : interval = [ 0.0 , 2.5 ] , c = 1.25 , f(c) = 3.515625 , error = 2.0
# Iter 4 : interval = [ 0.0 , 1.25 ] , c = 0.625 , f(c) = 1.259765625 , error = 2.0
# Iter 5 : interval = [ 0.0 , 0.625 ] , c = 0.3125 , f(c) = -1.278076171875 , error = 2.0
# Iter 6 : interval = [ 0.3125 , 0.625 ] , c = 0.46875 , f(c) = 0.127410888671875 , error = 0.6666666666666666
# Iter 7 : interval = [ 0.3125 , 0.46875 ] , c = 0.390625 , f(c) = -0.5397605895996094 , error = 0.4
# Iter 8 : interval = [ 0.390625 , 0.46875 ] , c = 0.4296875 , f(c) = -0.19746065139770508 , error = 0.18181818181818182
# Iter 9 : interval = [ 0.4296875 , 0.46875 ] , c = 0.44921875 , f(c) = -0.03286868333816528 , error = 0.08695652173913043
# Iter 10 : interval = [ 0.44921875 , 0.46875 ] , c = 0.458984375 , f(c) = 0.04780735820531845 , error = 0.0425531914893617
# Iter 11 : interval = [ 0.44921875 , 0.458984375 ] , c = 0.4541015625 , f(c) = 0.007603750564157963 , error = 0.021505376344086023
# Iter 12 : interval = [ 0.44921875 , 0.4541015625 ] , c = 0.45166015625 , f(c) = -0.01259881944861263 , error = 0.010810810810810811
# Iter 13 : interval = [ 0.45166015625 , 0.4541015625 ] , c = 0.452880859375 , f(c) = -0.002489128164597787 , error = 0.005390835579514825
# Iter 14 : interval = [ 0.452880859375 , 0.4541015625 ] , c = 0.4534912109375 , f(c) = 0.0025594120870664483 , error = 0.0026917900403768506
# Iter 15 : interval = [ 0.452880859375 , 0.4534912109375 ] , c = 0.45318603515625 , f(c) = 3.566726832104905e-05 , error = 0.0013468013468013469
# Iter 16 : interval = [ 0.452880859375 , 0.45318603515625 ] , c = 0.453033447265625 , f(c) = -0.0012265991107085483 , error = 0.0006736274840013472
# Iter 17 : interval = [ 0.453033447265625 , 0.45318603515625 ] , c = 0.4531097412109375 , f(c) = -0.0005954330881685621 , error = 0.0003367570298029971
# Iter 18 : interval = [ 0.4531097412109375 , 0.45318603515625 ] , c = 0.45314788818359375 , f(c) = -0.000279874701833549 , error = 0.00016836434043269636
# Iter 19 : interval = [ 0.45314788818359375 , 0.45318603515625 ] , c = 0.4531669616699219 , f(c) = -0.00012210166475501438 , error = 8.417862704659286e-05
# Iter 20 : interval = [ 0.4531669616699219 , 0.45318603515625 ] , c = 0.45317649841308594 , f(c) = -4.321668521889421e-05 , error = 4.2088427786780027e-05
# Iter 21 : interval = [ 0.45317649841308594 , 0.45318603515625 ] , c = 0.45318126678466797 , f(c) = -3.7745802003996687e-06 , error = 2.1043992466250697e-05
# Iter 22 : interval = [ 0.45318126678466797 , 0.45318603515625 ] , c = 0.453183650970459 , f(c) = 1.5946376122677464e-05 , error = 1.0521940877214211e-05
# Iter 23 : interval = [ 0.45318126678466797 , 0.453183650970459 ] , c = 0.4531824588775635 , f(c) = 6.085905976505046e-06 , error = 5.260984277548487e-06
# Iter 24 : interval = [ 0.45318126678466797 , 0.4531824588775635 ] , c = 0.4531818628311157 , f(c) = 1.155664892671382e-06 , error = 2.6304955985232397e-06
# Iter 25 : interval = [ 0.45318126678466797 , 0.4531818628311157 ] , c = 0.45318156480789185 , f(c) = -1.3094571524874254e-06 , error = 1.3152486642005753e-06
# Iter 26 : interval = [ 0.45318156480789185 , 0.4531818628311157 ] , c = 0.4531817138195038 , f(c) = -7.689600511895378e-08 , error = 6.576241158654777e-07
# Iter 27 : interval = [ 0.4531817138195038 , 0.4531818628311157 ] , c = 0.45318178832530975 , f(c) = 5.393844748624588e-07 , error = 3.2881200387406304e-07
# Iter 28 : interval = [ 0.4531817138195038 , 0.45318178832530975 ] , c = 0.45318175107240677 , f(c) = 2.3124424330944748e-07 , error = 1.6440601545169938e-07
# Iter 29 : interval = [ 0.4531817138195038 , 0.45318175107240677 ] , c = 0.4531817324459553 , f(c) = 7.71741213156929e-08 , error = 8.220301110451706e-08
# Iter 30 : interval = [ 0.4531817138195038 , 0.4531817324459553 ] , c = 0.45318172313272953 , f(c) = 1.390585424587698e-10 , error = 4.1101506396925424e-08
# Iter 31 : interval = [ 0.4531817138195038 , 0.45318172313272953 ] , c = 0.45318171847611666 , f(c) = -3.8378472844158296e-08 , error = 2.0550753409629445e-08
# Iter 32 : interval = [ 0.45318171847611666 , 0.45318172313272953 ] , c = 0.4531817208044231 , f(c) = -1.9119707594938973e-08 , error = 1.0275376652023038e-08
#   Interval [ -5 , 5 ] : root =  0.4531817208044231 , iterations =  32
# For Interval [0.4,0.45]
# You have not chosen a valid interval
# NEWTON-RAPHSON: Effect of initial guess on iteration count

# %% [markdown]
# ## Newton Raphson Method

# %%
m = methods()
n=1

x0 = 0
print(f"The intial guess is",x0)
tol =1e-8
n2,r2 =m.newton(func,dfunc,x0,tol)
if r1 is not None:
    print("The root is: ", r1)
    print("The number of iterations is: ", n1)
# Out:
# The intial guess is 0
# Iter 1 : x = 0.35714285714285715 , f(x) = -0.8473032069970845 , f'(x) = 9.38265306122449 , error = 1.0
# Iter 2 : x = 0.44744814728501514 , f(x) = -0.04761132557765535 , f'(x) = 8.336355471536166 , error = 0.20182291666666666
# Iter 3 : x = 0.453159435118196 , f(x) = -0.00018435968901364674 , f'(x) = 8.271828329255182 , error = 0.012603263643161756
# Iter 4 : x = 0.4531817227771845 , f(x) = -2.801860077283891e-09 , f'(x) = 8.271576902697308 , error = 4.918040130103216e-05

# %% [markdown]
# ### Sensitivity of iteration count to initial guess

# %%
print("NEWTON-RAPHSON: Effect of initial guess on iteration count")
print('\n')

initial_guesses = [0, 0.4, -2, 10]

for x0 in initial_guesses:
    print("\nInitial guess: x0 = ",x0)
    n2, r2 = m.newton(func, dfunc, x0, tol)
    if root_nr is not None:
        print("root = ",r2,", iterations = ",n2)
# Out:
# NEWTON-RAPHSON: Effect of initial guess on iteration count
#
#
#
# Initial guess: x0 =  0
# Iter 1 : x = 0.35714285714285715 , f(x) = -0.8473032069970845 , f'(x) = 9.38265306122449 , error = 1.0
# Iter 2 : x = 0.44744814728501514 , f(x) = -0.04761132557765535 , f'(x) = 8.336355471536166 , error = 0.20182291666666666
# Iter 3 : x = 0.453159435118196 , f(x) = -0.00018435968901364674 , f'(x) = 8.271828329255182 , error = 0.012603263643161756
# Iter 4 : x = 0.4531817227771845 , f(x) = -2.801860077283891e-09 , f'(x) = 8.271576902697308 , error = 4.918040130103216e-05
# root =  0.4531817227771845 , iterations =  4
#
# Initial guess: x0 =  0.4
# Iter 1 : x = 0.45135135135135135 , f(x) = -0.015158963931060754 , f'(x) = 8.292235208181154 , error = 0.11377245508982026
# Iter 2 : x = 0.45317944275861205 , f(x) = -1.8862180143131013e-05 , f'(x) = 8.27160262339645 , error = 0.004033923948828495
# Iter 3 : x = 0.453181723112372 , f(x) = -2.9331204132176936e-11 , f'(x) = 8.271576898916088 , error = 5.031874949183255e-06
# root =  0.453181723112372 , iterations =  3
#
# Initial guess: x0 =  -2
# Iter 1 : x = -0.7222222222222223 , f(x) = -19.13906035665295 , f'(x) = 25.675925925925927 , error = 1.769230769230769
# Iter 2 : x = 0.023186547528415535 , f(x) = -4.679139181047577 , f'(x) = 13.677001182561044 , error = 32.14832949308757
# Iter 3 : x = 0.3653038814812521 , f(x) = -0.7711254600636401 , f'(x) = 9.286086436738277 , error = 0.9365280559451009
# Iter 4 : x = 0.4483448336969087 , f(x) = -0.040140777198907074 , f'(x) = 8.326211597951403 , error = 0.1852167036941797
# Iter 5 : x = 0.4531658470385326 , f(x) = -0.00013132161662454678 , f'(x) = 8.271755996226997 , error = 0.010638518708171615
# Iter 6 : x = 0.4531817229440458 , f(x) = -1.4216539057088085e-09 , f'(x) = 8.27157690081496 , error = 3.503209575639604e-05
# root =  0.4531817229440458 , iterations =  6
#
# Initial guess: x0 =  10
# Iter 1 : x = 7.5 , f(x) = 128.125 , f'(x) = 77.75 , error = 0.3333333333333333
# Iter 2 : x = 5.852090032154341 , f(x) = 37.61683628692876 , f'(x) = 34.811612783159816 , error = 0.2815934065934066
# Iter 3 : x = 4.771507051950506 , f(x) = 11.064376810961917 , f'(x) = 15.500739913133145 , error = 0.22646576195713938
# Iter 4 : x = 4.057710363988048 , f(x) = 3.3631068180522092 , f'(x) = 6.587095098215379 , error = 0.17591119718582274
# Iter 5 : x = 3.5471504331069275 , f(x) = 1.215399152749157 , f'(x) = 2.086722521775009 , error = 0.14393523491867352
# Iter 6 : x = 2.964706365883599 , f(x) = 1.0377409521507772 , f'(x) = -1.1374376146381735 , error = 0.19645927634716612
# Iter 7 : x = 3.8770561411993114 , f(x) = 2.336054489197643 , f'(x) = 4.81590698924353 , error = 0.23532023836866336
# Iter 8 : x = 3.391985625008843 , f(x) = 0.9755494969053871 , f'(x) = 1.028900690676089 , error = 0.14300488557913738
# Iter 9 : x = 2.443838242325724 , f(x) = 2.0027638840634125 , f'(x) = -2.2966993285990824 , error = 0.3879746892661754
# Iter 10 : x = 3.3158565597103675 , f(x) = 0.9151857182953336 , f'(x) = 0.5627223377776787 , error = 0.2629843304985462
# Iter 11 : x = 1.6895025715079182 , f(x) = 3.4946515650119743 , f'(x) = -1.089779183715251 , error = 0.9626229729564085
# Iter 12 : x = 4.896254560565082 , f(x) = 13.113824956144711 , f'(x) = 17.372362317651948 , error = 0.6549398013094869
# Iter 13 : x = 4.141387449439969 , f(x) = 3.9511031441401485 , f'(x) = 7.473845726977103 , error = 0.18227396502763654
# Iter 14 : x = 3.6127301438872856 , f(x) = 1.3681886347847296 , f'(x) = 2.577235263233547 , error = 0.14633180018916372
# Iter 15 : x = 3.081855584508441 , f(x) = 0.9320935489002125 , f'(x) = -0.652476651820578 , error = 0.17225809088764277
# Iter 16 : x = 4.510402562089066 , f(x) = 7.497934616679181 , f'(x) = 11.885557947051907 , error = 0.3167227221773682
# Iter 17 : x = 3.8795584191316066 , f(x) = 2.3481342402226915 , f'(x) = 4.839102714522298 , error = 0.16260720288332878
# Iter 18 : x = 3.3943167578674496 , f(x) = 0.977965272504079 , f'(x) = 1.0437241480750927 , error = 0.14295709442539484
# Iter 19 : x = 2.4573208338891557 , f(x) = 1.9718611387794311 , f'(x) = -2.287214632451093 , error = 0.38130793140891084
# Iter 20 : x = 3.3194441828755545 , f(x) = 0.9172425384535359 , f'(x) = 0.5839104894213065 , error = 0.2597191883610954
# Iter 21 : x = 1.7485826294847544 , f(x) = 3.4237317803102876 , f'(x) = -1.3075331763791063 , error = 0.8983627807475576
# Iter 22 : x = 4.367049099139832 , f(x) = 5.9253705057322605 , f'(x) = 10.074666114936406 , error = 0.599596297227533
# Iter 23 : x = 3.7789035032329386 , f(x) = 1.9070313176406586 , f'(x) = 3.9356860149773922 , error = 0.15563922058441595
# Iter 24 : x = 3.294354860281396 , f(x) = 0.904439020482279 , f'(x) = 0.4373537924394171 , error = 0.1470845320258405
# Iter 25 : x = 1.2263745749439523 , f(x) = 3.4857425986574366 , f'(x) = 1.3427397449915457 , error = 1.6862550215801355
# Iter 26 : x = -1.3696181419316353 , f(x) = -39.874834441021584 , f'(x) = 38.80221555116769 , error = 1.8954135005939245
# Iter 27 : x = -0.34197490366243266 , f(x) = -10.646269376960673 , f'(x) = 19.138489155478847 , error = 3.005025302335054
# Iter 28 : x = 0.21430042666649907 , f(x) = -2.311425059764677 , f'(x) = 11.137568045277344 , error = 2.595773321509175
# Iter 29 : x = 0.42183451762496366 , f(x) = -0.2648642016953975 , f'(x) = 8.628149834030166 , error = 0.4919798695633886
# Iter 30 : x = 0.4525321998384494 , f(x) = -0.005374961609049045 , f'(x) = 8.278905377933587 , error = 0.06783535453265988
# Iter 31 : x = 0.4531814356206792 , f(x) = -2.378039441808255e-06 , f'(x) = 8.27158014208415 , error = 0.0014326177799860315
# Iter 32 : x = 0.45318172311586163 , f(x) = -4.654054919228656e-13 , f'(x) = 8.271576898876722 , error = 6.3439271212938e-07
# root =  0.45318172311586163 , iterations =  32

# %% [markdown]
# ##  Problematic initial guesses for Newton Raphson
# ### $f'(x) = 3x^2 - 14x +14=0$ at $x = \frac{(14 \pm \sqrt{28})}{6}$

# %%
# f'(x) = 3x^2 - 14x + 14 = 0  at x = (14 ± sqrt(28)) / 6
crit1 = (14 + np.sqrt(28)) / 6   # ≈ 3.215  (local min of f)
crit2 = (14 - np.sqrt(28)) / 6   # ≈ 1.118  (local max of f)

print("Critical points of f (where f'(x) = 0):")
print(f"  x = {crit1:.6f},  f'(x) = {dfunc(crit1):.2e}")
print(f"  x = {crit2:.6f},  f'(x) = {dfunc(crit2):.2e}")
print()

problematic_guesses = [
    (crit1,       "exactly at local minimum (f'=0, division by zero)"),
    (crit1 + 0.001, "just past local minimum (tiny f', huge step)"),
    (crit2,       "exactly at local maximum (f'=0, division by zero)"),
    (crit2 - 0.001, "just before local maximum"),
]

for x0, description in problematic_guesses:
    print(f"x0 = {x0:.6f}  [{description}]")
    try:
        n_nr, root_nr = m.newton(func, dfunc, x0, tol)
        print(f"  → root = {root_nr}, iterations = {n_nr}\n")
    except Exception as e:
        print(f"  → ERROR: {e}\n")
# Out:
# Critical points of f (where f'(x) = 0):
#   x = 3.215250,  f'(x) = 0.00e+00
#   x = 1.451416,  f'(x) = 0.00e+00
#
# x0 = 3.215250  [exactly at local minimum (f'=0, division by zero)]
# Iter 1 : x = -inf , f(x) = -inf , f'(x) = inf , error = nan
#   → root = -inf, iterations = 1
#
# x0 = 3.216250  [just past local minimum (tiny f', huge step)]
# Iter 1 : x = -164.38983443322257 , f(x) = -4633948.371003868 , f'(x) = 83387.5106770121 , error = 1.0195647769103875
# Iter 2 : x = -108.81858241500717 , f(x) = -1372992.336687943 , f'(x) = 37061.91179024523 , error = 0.5106779631283965
# Iter 3 : x = -71.77267003848164 , f(x) = -406792.7458668727 , f'(x) = 16472.76587389702 , error = 0.5161562521871207
# Iter 4 : x = -47.07780404081197 , f(x) = -120517.78807824837 , f'(x) = 7322.048156486643 , error = 0.5245543308745151
# Iter 5 : x = -30.618230776262898 , f(x) = -35699.84584774936 , f'(x) = 3255.083398473158 , error = 0.5375742767380775
# Iter 6 : x = -19.650817202621475 , f(x) = -10571.447543278784 , f'(x) = 1447.575291029233 , error = 0.5581148845137258
# Iter 7 : x = -12.347951777388612 , f(x) = -3127.8905468848616 , f'(x) = 644.2870641735843 , error = 0.5914232219958748
# Iter 8 : x = -7.493142918395065 , f(x) = -923.6532615230228 , f'(x) = 287.3455732440132 , error = 0.6479002084793261
# Iter 9 : x = -4.278709332050379 , f(x) = -271.3852499576523 , f'(x) = 128.8239912932303 , error = 0.7512624338060169
# Iter 10 : x = -2.172073392321398 , f(x) = -78.68197843033552 , f'(x) = 58.56273595739133 , error = 0.969873277383836
# Iter 11 : x = -0.8285231441297425 , f(x) = -21.973218430025717 , f'(x) = 27.6586758188923 , error = 1.6216206604619154
# Iter 12 : x = -0.03408097437782409 , f(x) = -5.485303816479803 , f'(x) = 14.480618179733163 , error = 23.310430064137144
# Iter 13 : x = 0.3447221781116839 , f(x) = -0.9647586653966078 , f'(x) = 9.530389646682616 , error = 1.0988650471069559
# Iter 14 : x = 0.44595189705947375 , f(x) = -0.060097268841648344 , f'(x) = 8.353292724640198 , error = 0.22699694656594213
# Iter 15 : x = 0.45314633772170215 , f(x) = -0.00029270007195769665 , f'(x) = 8.271976082067942 , error = 0.01587663865584822
# Iter 16 : x = 0.4531817222621135 , f(x) = -7.06230895985982e-09 , f'(x) = 8.271576908507777 , error = 7.808024612009682e-05
#   → root = 0.4531817222621135, iterations = 16
#
# x0 = 1.451416  [exactly at local maximum (f'=0, division by zero)]
# Iter 1 : x = -inf , f(x) = -inf , f'(x) = inf , error = nan
#   → root = -inf, iterations = 1
#
# x0 = 1.450416  [just before local maximum]
# Iter 1 : x = -684.3793815519806 , f(x) = -323834499.48245364 , f'(x) = 1414720.725022142 , error = 1.0021193160821942
# Iter 2 : x = -455.47589992850664 , f(x) = -95950843.53260097 , f'(x) = 628765.5488460481 , error = 0.5025589315689449
# Iter 3 : x = -302.87395838018824 , f(x) = -28429799.8516686 , f'(x) = 279452.13941197464 , error = 0.5038463602630436
# Iter 4 : x = -201.13990148053165 , f(x) = -8423591.062448828 , f'(x) = 124201.73852352137 , error = 0.5057875446434156
# Iter 5 : x = -133.31805645173952 , f(x) = -2495843.078724522 , f'(x) = 55201.56531853196 , error = 0.508722125373492
# Iter 6 : x = -88.10479004665387 , f(x) = -739485.0277511891 , f'(x) = 24534.829148148034 , error = 0.5131760302833024
# Iter 7 : x = -57.96457495544719 , f(x) = -219090.4564621308 , f'(x) = 10905.179898673228 , error = 0.5199764703592341
# Iter 8 : x = -37.87408048421098 , f(x) = -64904.68114809525 , f'(x) = 4847.575044352427 , error = 0.5304549764478528
# Iter 9 : x = -24.48497757105212 , f(x) = -19223.478517253956 , f'(x) = 2155.3320659595056 , error = 0.5468292905029412
# Iter 10 : x = -15.565944248594638 , f(x) = -5690.620377817869 , f'(x) = 958.8190805313944 , error = 0.5729837637869435
# Iter 11 : x = -9.630913862399126 , f(x) = -1682.4249242741014 , f'(x) = 427.0962995484427 , error = 0.6162478941242505
# Iter 12 : x = -5.691697048643344 , f(x) = -495.8365553515449 , f'(x) = 190.87000456161286 , error = 0.6920988204554426
# Iter 13 : x = -3.0939260867241347 , f(x) = -144.93784758062725 , f'(x) = 86.03210110447424 , error = 0.839635753764804
# Iter 14 : x = -1.4092311214736635 , f(x) = -41.42939985475837 , f'(x) = 39.687032761821044 , error = 1.1954710193234657
# Iter 15 : x = -0.36532844163881606 , f(x) = -11.0976107879045 , f'(x) = 19.51499279375416 , error = 2.8574361064034193
# Iter 16 : x = 0.20334257480431217 , f(x) = -2.434233521829709 , f'(x) = 11.277248560923772 , error = 2.796615598038885
# Iter 17 : x = 0.41919607033374917 , f(x) = -0.2876690587676123 , f'(x) = 8.658431051477283 , error = 0.5149225167058031
# Iter 18 : x = 0.45242022573295754 , f(x) = -0.006302055380182914 , f'(x) = 8.280169021695375 , error = 0.07343649445685707
# Iter 19 : x = 0.4531813279959271 , f(x) = -3.2682662691740916e-06 , f'(x) = 8.271581356189477 , error = 0.0016794651852390845
# Iter 20 : x = 0.45318172311581145 , f(x) = -8.810729923425242e-13 , f'(x) = 8.271576898877289 , error = 8.718795667059682e-07
#   → root = 0.45318172311581145, iterations = 20
# /Users/aradhikapaul/Desktop/hw2/methods.py:40: RuntimeWarning: divide by zero encountered in scalar divide
#   delta_x = f(x0)/df(x0)
# /Users/aradhikapaul/Desktop/hw2/methods.py:45: RuntimeWarning: invalid value encountered in scalar divide
#   error = abs((delta_x)/max(abs(x1), 1e-16))
# /Users/aradhikapaul/Desktop/hw2/methods.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   delta_x = f(x1)/df(x1)
